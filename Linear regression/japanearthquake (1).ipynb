# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
eq=pd.read_csv("japanearthquake.csv")

# %%
eq.shape
# Out:
# (215, 22)

# %%
eq.head()
# Out:
#                        time  latitude  longitude   depth   mag magType   nst  \
# 0  2021-08-16T04:35:51.680Z   17.8435   -66.8898   12.00  2.57      md  17.0
# 1  2021-08-16T01:33:40.550Z   17.9775   -66.7873   17.00  2.56      md  14.0
# 2  2021-08-15T22:10:12.050Z   17.9833   -66.7738   11.00  2.75      md  17.0
# 3  2021-08-15T21:38:27.410Z   18.2806   -68.0030  103.00  3.64      md  11.0
# 4  2021-08-15T16:05:05.782Z   18.5392   -73.5810   12.04  4.10      mb   NaN
#
#    gap    dmin   rms  ...                   updated  \
# 0  231  0.1993  0.21  ...  2021-08-16T05:00:30.524Z
# 1  179  0.1925  0.15  ...  2021-08-16T06:14:16.458Z
# 2  175  0.1778  0.12  ...  2021-08-16T00:56:25.321Z
# 3  156  0.4445  0.21  ...  2021-08-16T06:21:13.582Z
# 4   95  1.7390  0.49  ...  2021-08-15T17:08:23.040Z
#
#                                         place        type horizontalError  \
# 0             14 km S of Guánica, Puerto Rico  earthquake            0.73
# 1             3 km ESE of Indios, Puerto Rico  earthquake            0.46
# 2         3 km S of Magas Arriba, Puerto Rico  earthquake            0.43
# 3  53 km SE of Punta Cana, Dominican Republic  earthquake            2.06
# 4     7 km WNW of Petit Trou de Nippes, Haiti  earthquake            4.20
#
#   depthError  magError  magNst    status  locationSource magSource
# 0       0.55     0.170       7  reviewed              pr        pr
# 1       0.34     0.170       5  reviewed              pr        pr
# 2       0.31     0.290       8  reviewed              pr        pr
# 3       1.20     0.010       3  reviewed              pr        pr
# 4       6.30     0.212       6  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
eq.describe
# Out:
# <bound method NDFrame.describe of                          time  latitude  longitude   depth   mag magType  \
# 0    2021-08-16T04:35:51.680Z   17.8435   -66.8898   12.00  2.57      md
# 1    2021-08-16T01:33:40.550Z   17.9775   -66.7873   17.00  2.56      md
# 2    2021-08-15T22:10:12.050Z   17.9833   -66.7738   11.00  2.75      md
# 3    2021-08-15T21:38:27.410Z   18.2806   -68.0030  103.00  3.64      md
# 4    2021-08-15T16:05:05.782Z   18.5392   -73.5810   12.04  4.10      mb
# ..                        ...       ...        ...     ...   ...     ...
# 210  2021-07-18T02:55:39.660Z   18.0571   -66.7930   11.00  3.12      md
# 211  2021-07-17T16:48:18.350Z   17.9243   -66.9268   10.00  2.90      md
# 212  2021-07-17T13:24:00.800Z   18.2090   -67.2168  101.00  3.15      md
# 213  2021-07-17T05:06:52.430Z   19.6276   -63.5315   41.00  3.99      md
# 214  2021-07-17T02:43:34.920Z   17.9451   -66.8485   12.00  2.72      md
#
#       nst  gap    dmin   rms  ...                   updated  \
# 0    17.0  231  0.1993  0.21  ...  2021-08-16T05:00:30.524Z
# 1    14.0  179  0.1925  0.15  ...  2021-08-16T06:14:16.458Z
# 2    17.0  175  0.1778  0.12  ...  2021-08-16T00:56:25.321Z
# 3    11.0  156  0.4445  0.21  ...  2021-08-16T06:21:13.582Z
# 4     NaN   95  1.7390  0.49  ...  2021-08-15T17:08:23.040Z
# ..    ...  ...     ...   ...  ...                       ...
# 210  17.0   98  0.1873  0.16  ...  2021-07-18T04:57:29.510Z
# 211  21.0  215  0.1258  0.14  ...  2021-07-17T17:38:14.225Z
# 212  18.0  154  0.0724  0.28  ...  2021-07-17T14:43:46.420Z
# 213  16.0  340  2.1929  0.24  ...  2021-08-04T05:41:42.040Z
# 214  15.0  200  0.1972  0.09  ...  2021-07-17T03:38:03.547Z
#
#                                           place        type horizontalError  \
# 0               14 km S of Guánica, Puerto Rico  earthquake            0.73
# 1               3 km ESE of Indios, Puerto Rico  earthquake            0.46
# 2           3 km S of Magas Arriba, Puerto Rico  earthquake            0.43
# 3    53 km SE of Punta Cana, Dominican Republic  earthquake            2.06
# 4       7 km WNW of Petit Trou de Nippes, Haiti  earthquake            4.20
# ..                                          ...         ...             ...
# 210           4 km N of Guayanilla, Puerto Rico  earthquake            0.30
# 211            5 km SSW of Guánica, Puerto Rico  earthquake            0.51
# 212             8 km W of Mayagüez, Puerto Rico  earthquake            1.72
# 213          163 km NNW of The Valley, Anguilla  earthquake            2.98
# 214       5 km SE of Maria Antonia, Puerto Rico  earthquake            0.48
#
#     depthError  magError  magNst    status  locationSource magSource
# 0         0.55     0.170       7  reviewed              pr        pr
# 1         0.34     0.170       5  reviewed              pr        pr
# 2         0.31     0.290       8  reviewed              pr        pr
# 3         1.20     0.010       3  reviewed              pr        pr
# 4         6.30     0.212       6  reviewed              us        us
# ..         ...       ...     ...       ...             ...       ...
# 210       0.48     0.140       3  reviewed              pr        pr
# 211       0.64     0.270      13  reviewed              pr        pr
# 212       0.89     0.140      13  reviewed              pr        pr
# 213      19.17     0.060       4  reviewed              pr        pr
# 214       0.46     0.070       6  reviewed              pr        pr
#
# [215 rows x 22 columns]>

# %%
eq.head()
# Out:
#                        time  latitude  longitude   depth   mag magType   nst  \
# 0  2021-08-16T04:35:51.680Z   17.8435   -66.8898   12.00  2.57      md  17.0
# 1  2021-08-16T01:33:40.550Z   17.9775   -66.7873   17.00  2.56      md  14.0
# 2  2021-08-15T22:10:12.050Z   17.9833   -66.7738   11.00  2.75      md  17.0
# 3  2021-08-15T21:38:27.410Z   18.2806   -68.0030  103.00  3.64      md  11.0
# 4  2021-08-15T16:05:05.782Z   18.5392   -73.5810   12.04  4.10      mb   NaN
#
#    gap    dmin   rms  ...                   updated  \
# 0  231  0.1993  0.21  ...  2021-08-16T05:00:30.524Z
# 1  179  0.1925  0.15  ...  2021-08-16T06:14:16.458Z
# 2  175  0.1778  0.12  ...  2021-08-16T00:56:25.321Z
# 3  156  0.4445  0.21  ...  2021-08-16T06:21:13.582Z
# 4   95  1.7390  0.49  ...  2021-08-15T17:08:23.040Z
#
#                                         place        type horizontalError  \
# 0             14 km S of Guánica, Puerto Rico  earthquake            0.73
# 1             3 km ESE of Indios, Puerto Rico  earthquake            0.46
# 2         3 km S of Magas Arriba, Puerto Rico  earthquake            0.43
# 3  53 km SE of Punta Cana, Dominican Republic  earthquake            2.06
# 4     7 km WNW of Petit Trou de Nippes, Haiti  earthquake            4.20
#
#   depthError  magError  magNst    status  locationSource magSource
# 0       0.55     0.170       7  reviewed              pr        pr
# 1       0.34     0.170       5  reviewed              pr        pr
# 2       0.31     0.290       8  reviewed              pr        pr
# 3       1.20     0.010       3  reviewed              pr        pr
# 4       6.30     0.212       6  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
eq['nst']=eq['nst'].fillna(0)
eq['rms']=eq['rms'].fillna(0)

# %%
eq.head()
# Out:
#                        time  latitude  longitude   depth   mag magType   nst  \
# 0  2021-08-16T04:35:51.680Z   17.8435   -66.8898   12.00  2.57      md  17.0
# 1  2021-08-16T01:33:40.550Z   17.9775   -66.7873   17.00  2.56      md  14.0
# 2  2021-08-15T22:10:12.050Z   17.9833   -66.7738   11.00  2.75      md  17.0
# 3  2021-08-15T21:38:27.410Z   18.2806   -68.0030  103.00  3.64      md  11.0
# 4  2021-08-15T16:05:05.782Z   18.5392   -73.5810   12.04  4.10      mb   0.0
#
#    gap    dmin   rms  ...                   updated  \
# 0  231  0.1993  0.21  ...  2021-08-16T05:00:30.524Z
# 1  179  0.1925  0.15  ...  2021-08-16T06:14:16.458Z
# 2  175  0.1778  0.12  ...  2021-08-16T00:56:25.321Z
# 3  156  0.4445  0.21  ...  2021-08-16T06:21:13.582Z
# 4   95  1.7390  0.49  ...  2021-08-15T17:08:23.040Z
#
#                                         place        type horizontalError  \
# 0             14 km S of Guánica, Puerto Rico  earthquake            0.73
# 1             3 km ESE of Indios, Puerto Rico  earthquake            0.46
# 2         3 km S of Magas Arriba, Puerto Rico  earthquake            0.43
# 3  53 km SE of Punta Cana, Dominican Republic  earthquake            2.06
# 4     7 km WNW of Petit Trou de Nippes, Haiti  earthquake            4.20
#
#   depthError  magError  magNst    status  locationSource magSource
# 0       0.55     0.170       7  reviewed              pr        pr
# 1       0.34     0.170       5  reviewed              pr        pr
# 2       0.31     0.290       8  reviewed              pr        pr
# 3       1.20     0.010       3  reviewed              pr        pr
# 4       6.30     0.212       6  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
x=eq.iloc[:,1:3].values
y=eq.iloc[:,9:10].values

# %%
print(x)
#print(y)
# Out:
# [[ 17.8435     -66.8898    ]
#  [ 17.9775     -66.7873    ]
#  [ 17.9833     -66.7738    ]
#  [ 18.2806     -68.003     ]
#  [ 18.5392     -73.581     ]
#  [ 17.9595     -66.9238    ]
#  [ 19.3821     -64.7703    ]
#  [ 18.4762     -73.7504    ]
#  [ 17.8825     -66.8861    ]
#  [ 18.5103     -73.6685    ]
#  [ 17.8476     -66.8896    ]
#  [ 17.8736     -66.8875    ]
#  [ 18.4388     -74.0965    ]
#  [ 17.8411     -66.8851    ]
#  [ 17.8511     -66.886     ]
#  [ 18.3711     -74.0992    ]
#  [ 18.5997     -73.5811    ]
#  [ 17.9881     -66.9516    ]
#  [ 18.5174     -74.0251    ]
#  [ 18.4717     -74.0298    ]
#  [ 18.0375     -66.7931    ]
#  [ 18.0308     -66.7996    ]
#  [ 18.591      -73.6128    ]
#  [ 18.4743     -73.6174    ]
#  [ 18.5398     -73.7125    ]
#  [ 18.4932     -73.5949    ]
#  [ 18.476      -73.6736    ]
#  [ 18.4906     -73.7093    ]
#  [ 18.4851     -73.5484    ]
#  [ 18.4506     -73.5952    ]
#  [ 17.9726     -67.1663    ]
#  [ 18.2706     -73.431     ]
#  [ 18.4531     -73.4612    ]
#  [ 18.3887     -73.8245    ]
#  [ 18.4079     -73.4753    ]
#  [ 17.9178     -66.8471    ]
#  [ 17.9486     -67.1651    ]
#  [ 18.0011     -66.8256    ]
#  [ 17.871      -66.8628    ]
#  [ 17.7981     -66.8951    ]
#  [ 17.9371     -66.3346    ]
#  [ 17.9413     -66.3366    ]
#  [ 17.9486     -66.3308    ]
#  [ 17.8063     -66.812     ]
#  [ 17.9245     -66.8395    ]
#  [ 17.9458     -67.0845    ]
#  [ 17.967      -66.7696    ]
#  [ 18.03       -66.6765    ]
#  [ 17.927      -66.7525    ]
#  [ 17.9526     -67.113     ]
#  [ 17.9208     -66.9068    ]
#  [ 17.9551     -67.1241    ]
#  [ 17.9336     -67.1165    ]
#  [ 18.4166     -66.0701    ]
#  [ 17.9296     -67.0945    ]
#  [ 17.948      -67.1005    ]
#  [ 19.1305     -65.249     ]
#  [ 18.2425     -63.9496    ]
#  [ 17.918      -66.8991    ]
#  [ 17.9393     -66.8901    ]
#  [ 18.2521     -67.7625    ]
#  [ 18.0315     -66.8368    ]
#  [ 18.0058     -66.5255    ]
#  [ 17.9415     -67.102     ]
#  [ 17.9438     -66.9383    ]
#  [ 17.9388     -66.939     ]
#  [ 18.4831     -67.5053    ]
#  [ 17.952      -66.8341    ]
#  [ 17.98       -67.1511    ]
#  [ 18.795      -64.8285    ]
#  [ 17.9135     -66.9175    ]
#  [ 17.9813     -66.8361    ]
#  [ 17.9888     -66.748     ]
#  [ 17.9171     -66.9468    ]
#  [ 17.962      -66.9325    ]
#  [ 17.9308     -66.9195    ]
#  [ 17.9668     -66.9836    ]
#  [ 17.8965     -66.8673    ]
#  [ 17.9795     -66.9066    ]
#  [ 17.9415     -67.0303    ]
#  [ 17.9863     -66.9511    ]
#  [ 18.1691     -67.3001    ]
#  [ 19.1483     -67.7433    ]
#  [ 17.9256     -66.9013    ]
#  [ 17.8731     -66.855     ]
#  [ 17.9358     -67.074     ]
#  [ 17.947      -67.0708    ]
#  [ 17.94916667 -67.09566667]
#  [ 17.962      -67.0895    ]
#  [ 18.36116667 -68.33916667]
#  [ 18.64816667 -68.67266667]
#  [ 17.9605     -67.1008    ]
#  [ 17.9678     -67.1093    ]
#  [ 18.8608     -67.3476    ]
#  [ 19.0538     -63.9173    ]
#  [ 17.967      -66.8683    ]
#  [ 19.1377     -69.3615    ]
#  [ 17.956      -67.0971    ]
#  [ 17.9376     -67.1121    ]
#  [ 17.942      -67.1086    ]
#  [ 17.8258     -65.6668    ]
#  [ 17.9605     -67.0863    ]
#  [ 17.9271     -66.8595    ]
#  [ 17.9545     -66.9575    ]
#  [ 18.496      -66.9603    ]
#  [ 17.9676     -66.9678    ]
#  [ 18.3996     -68.3008    ]
#  [ 17.9595     -67.008     ]
#  [ 17.954      -67.0073    ]
#  [ 19.0905     -66.2823    ]
#  [ 18.015      -66.772     ]
#  [ 18.5051     -65.0086    ]
#  [ 17.9388     -66.9921    ]
#  [ 19.2678     -68.0976    ]
#  [ 18.4316     -67.299     ]
#  [ 17.7923     -65.087     ]
#  [ 17.9421     -67.056     ]
#  [ 17.9348     -66.8426    ]
#  [ 17.9533     -67.1036    ]
#  [ 17.9453     -67.1056    ]
#  [ 17.9438     -67.108     ]
#  [ 17.9451     -67.1103    ]
#  [ 18.1398     -68.156     ]
#  [ 17.9519     -67.0895    ]
#  [ 18.7755     -64.3838    ]
#  [ 17.9788     -66.984     ]
#  [ 17.9433     -67.0888    ]
#  [ 17.9588     -67.0718    ]
#  [ 19.5833     -67.6433    ]
#  [ 18.1054     -68.6151    ]
#  [ 17.9566     -66.9195    ]
#  [ 18.948      -66.7666    ]
#  [ 17.8725     -66.88      ]
#  [ 18.0568     -66.8191    ]
#  [ 17.8688     -66.876     ]
#  [ 17.939      -67.1028    ]
#  [ 18.0423     -66.8876    ]
#  [ 17.9503     -66.9205    ]
#  [ 18.5923     -66.392     ]
#  [ 17.9311     -67.1116    ]
#  [ 19.6416     -63.8926    ]
#  [ 17.9701     -67.2423    ]
#  [ 17.9638     -67.2438    ]
#  [ 17.9745     -66.9703    ]
#  [ 17.9615     -66.9566    ]
#  [ 17.9733     -68.2698    ]
#  [ 17.9343     -67.0918    ]
#  [ 17.957      -66.9641    ]
#  [ 18.4625     -68.425     ]
#  [ 17.982      -67.1541    ]
#  [ 17.9861     -66.8526    ]
#  [ 18.1841     -66.1696    ]
#  [ 19.5706     -68.2848    ]
#  [ 18.3968     -65.157     ]
#  [ 17.9646     -67.093     ]
#  [ 17.972      -66.9343    ]
#  [ 18.6598     -66.4466    ]
#  [ 19.2341     -64.7695    ]
#  [ 18.4636     -67.2126    ]
#  [ 17.951      -67.0996    ]
#  [ 17.9633     -66.9543    ]
#  [ 17.9666     -67.0161    ]
#  [ 17.9525     -65.9688    ]
#  [ 17.894      -66.898     ]
#  [ 19.535      -63.5095    ]
#  [ 19.6066     -63.6881    ]
#  [ 17.9931     -66.768     ]
#  [ 17.9315     -66.8423    ]
#  [ 17.9548     -67.1796    ]
#  [ 18.0365     -66.7925    ]
#  [ 17.9643     -67.104     ]
#  [ 18.4255     -67.3533    ]
#  [ 17.9468     -67.1843    ]
#  [ 18.0016     -66.9791    ]
#  [ 17.9465     -67.0875    ]
#  [ 18.2105     -67.2395    ]
#  [ 19.2271     -65.9813    ]
#  [ 19.1895     -66.0013    ]
#  [ 19.1811     -66.0073    ]
#  [ 19.2025     -65.9921    ]
#  [ 17.9538     -67.1076    ]
#  [ 17.9471     -67.109     ]
#  [ 19.0236     -68.444     ]
#  [ 18.0078     -67.0583    ]
#  [ 19.1615     -66.4465    ]
#  [ 18.6818     -66.0713    ]
#  [ 18.0113     -66.7975    ]
#  [ 17.958      -67.1053    ]
#  [ 17.949      -67.0943    ]
#  [ 17.9596     -67.1003    ]
#  [ 19.7691     -75.5106    ]
#  [ 17.9578     -67.0198    ]
#  [ 17.9591     -67.096     ]
#  [ 17.9383     -66.8531    ]
#  [ 19.2225     -65.0258    ]
#  [ 17.953      -67.1078    ]
#  [ 17.9588     -67.0831    ]
#  [ 17.9253     -66.8973    ]
#  [ 17.9526     -67.0986    ]
#  [ 17.9533     -67.0941    ]
#  [ 17.966      -67.108     ]
#  [ 17.9476     -67.0993    ]
#  [ 17.9416     -67.0975    ]
#  [ 17.9541     -67.106     ]
#  [ 17.9553     -67.0951    ]
#  [ 17.9416     -67.103     ]
#  [ 17.9441     -67.0876    ]
#  [ 17.9643     -67.0958    ]
#  [ 17.9443     -67.0966    ]
#  [ 17.9396     -67.1035    ]
#  [ 18.0571     -66.793     ]
#  [ 17.9243     -66.9268    ]
#  [ 18.209      -67.2168    ]
#  [ 19.6276     -63.5315    ]
#  [ 17.9451     -66.8485    ]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regg=LinearRegression()
regg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regg.intercept_)
# Out:
# [-8.94431367]

# %%
print(regg.coef_)
# Out:
# [[ 0.20060496 -0.08217968]]

# %%
ypre=regg.predict(x_test)

# %%
print("Mean squared error: %.2f" % np.mean((regg.predict(x_test) - y_test) ** 2))
print('Variance score: %.2f' % regg.score(x_test, y_test))
r2_score = regg.score(x_test,y_test)
print(r2_score)
# Out:
# Mean squared error: 0.02
# Variance score: 0.74
# 0.7394807232277694

# %%
para=[[17.8435,-68.8898]]

# %%
predeq=regg.predict(para)
print(predeq)
# Out:
# [[0.29652288]]

# %%
if(predeq > 0.1):
    print("earthquake")
else:
    print("no earthquake")
# Out:
# earthquake
